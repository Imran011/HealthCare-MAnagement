# %%
from tkinter import *
from tkinter import messagebox

root = Tk()

def getvals():
    if namevalue.get()=='doctor1' and passvalue.get()=='doctor1':
        messagebox.showinfo("Who is here","You entered as Cardiologists")
    elif namevalue.get()=='doctor2' and passvalue.get()=='doctor2':
         messagebox.showinfo("Who is here","You entered as Orthopedics")
    else:
         messagebox.showinfo("who is here","You entered as Family Physician")
        
    def appointed():
        with open("appoint.txt","r") as d:
            dtd = d.read()
            messagebox.showinfo("Appointed People", dtd)
        
    def cen():
        messagebox.showinfo("Contact us", "Phone Number :9876543533"+"\n"+"Email :imrankhan342@gmail.com"+"\n"+"Website :www.imranhospital.com")
        
    def appoint():
            with open("appoint.txt","a") as f:
                f.write("Name: "+nameentry.get() +"\n")
                f.write("Mobile: "+mobileentry.get()+"\n")
                f.write("Appointment no: "+app0entry.get()+"\n")
                f.write("Appointment date: "+app1entry.get()+"\n")
                f.write("Appointment Time: "+app2entry.get()+"\n"+"\n")
            Label(ui,text="Appointment taken successfully",font=("corbel",20,"bold")).place(x=250,y=320)
                
                
    if namevalue.get()=='doctor1' and passvalue.get()=='doctor1' or namevalue.get()=='doctor2' and passvalue.get()=='doctor2' or namevalue.get()=='doctor3' and passvalue.get()=='doctor3':
        
            
        ui=Toplevel()
        ui.geometry('800x600')
        ui.maxsize(800,600)
        a=Canvas(ui,height=600,width=800,bd=2)
        img2=PhotoImage(file="123.png")
        a.create_image(0,0,anchor=NW,image=img2)
        a.place(x=0,y=0)

        
        name = Label(ui, text="Name",font=("corbel",20,"bold"))
        mobile = Label(ui, text="Mobile Number",font=("corbel",20,"bold"))
        app0 = Label(ui, text="Appointment No",font=("corbel",20,"bold"))
        app1 = Label(ui, text="Appointment date",font=("corbel",20,"bold"))
        app2 = Label(ui, text="Appointment time",font=("corbel",20,"bold"))
        name.place(x=30,y=50)
        mobile.place(x=30,y=80)
        app0.place(x=30,y=110)
        app1.place(x=30,y=140)
        app2.place(x=30,y=170)
       
        
        namevalue1=StringVar()
        mobilevalue = StringVar()
        app0value = IntVar()
        app1value = IntVar()
        app2value = IntVar()
        app0value.set("")
        app1value.set("")
        app2value.set("")
        
        nameentry = Entry(ui, textvariable=namevalue1,font=("corbel",20,"bold"))
        mobileentry = Entry(ui, textvariable=mobilevalue,font=("corbel",20,"bold"))
        app0entry = Entry(ui, textvariable=app0value,font=("corbel",20,"bold"))
        app1entry = Entry(ui, textvariable=app1value,font=("corbel",20,"bold"))
        app2entry = Entry(ui, textvariable=app2value,font=("corbel",20,"bold"))
        nameentry.place(x=350,y=50)
        mobileentry.place(x=350,y=80)
        app0entry.place(x=350,y=110)
        app1entry.place(x=350,y=140)
        app2entry.place(x=350,y=170)
        
        Button(ui,text="Appointed", command=appoint,font=("corbel",20,"bold")).place(x=460, y=230)
        Button(ui,text="Contact Us", command=cen,font=("corbel",20,"bold")).place(x=50, y=500)
        Button(ui,text="Appointed people", command=appointed,font=("corbel",20,"bold")).place(x=380, y=500)
        ui.mainloop()

        
        
    else:
        messagebox.showinfo("Error","Password incorrect \nPlease enter again")


root.geometry("800x600")
root.maxsize(800,600)
root.title("Online healthcare Management System")
c=Canvas(root,height=600,width=800,bg="black",bd=0)
img=PhotoImage(file="hospital.png")
c.create_image(0,0,anchor=NW,image=img)
c.place(x=0,y=0)

#Text for our form
name = Label(root, text="Username",font=("corbel",20,"bold"))
password = Label(root, text="Password",font=("corbel",20,"bold"))


#Pack text for our form
name.place(x=150,y=150)
password.place(x=150,y=200)


# Tkinter variable for storing entries
namevalue = StringVar()
passvalue = StringVar()

#Entries for our form
nameentry = Entry(root, textvariable=namevalue,font=("corbel",20,"bold"))
passentry = Entry(root, textvariable=passvalue,show="*",font=("corbel",20,"bold"))

# Packing the Entries
nameentry.place(x=300,y=150)
passentry.place(x=300,y=200)
#Button & packing it and assigning it a command
Button(text="Submit", command=getvals,font=("corbel",20,"bold")).place(x=350,y=280)

root.mainloop()

# %%
from tkinter import * 

def show():
    p = password.get() #get password from entry
    print(p)


app = Tk()   
password = StringVar() #Password variable
passEntry = Entry(app, textvariable=password, show='*').pack() 
submit = Button(app, text='Show Console',command=show).pack()      
app.mainloop()
